# %% [markdown]
# # 🐱 Chat Clip Classifier

# %%
# 📦 Installation des dépendances
# !pip install opencv-python moviepy torch torchvision ftfy regex tqdm
# !pip install git+https://github.com/openai/CLIP.git
# Out:
# Requirement already satisfied: opencv-python in c:\users\nacer\anaconda3\lib\site-packages (4.11.0.86)
# Requirement already satisfied: moviepy in c:\users\nacer\anaconda3\lib\site-packages (2.1.2)
# Requirement already satisfied: torch in c:\users\nacer\anaconda3\lib\site-packages (2.6.0)
# Requirement already satisfied: torchvision in c:\users\nacer\anaconda3\lib\site-packages (0.21.0)
# Requirement already satisfied: ftfy in c:\users\nacer\anaconda3\lib\site-packages (6.3.1)
# Requirement already satisfied: regex in c:\users\nacer\anaconda3\lib\site-packages (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\nacer\anaconda3\lib\site-packages (4.66.5)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\nacer\anaconda3\lib\site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in c:\users\nacer\anaconda3\lib\site-packages (from moviepy) (5.1.1)
# Requirement already satisfied: imageio<3.0,>=2.5 in c:\users\nacer\anaconda3\lib\site-packages (from moviepy) (2.33.1)
# Requirement already satisfied: imageio_ffmpeg>=0.2.0 in c:\users\nacer\anaconda3\lib\site-packages (from moviepy) (0.6.0)
# Requirement already satisfied: proglog<=1.0.0 in c:\users\nacer\anaconda3\lib\site-packages (from moviepy) (0.1.11)
# Requirement already satisfied: python-dotenv>=0.10 in c:\users\nacer\anaconda3\lib\site-packages (from moviepy) (0.21.0)
# Requirement already satisfied: pillow<11.0,>=9.2.0 in c:\users\nacer\anaconda3\lib\site-packages (from moviepy) (10.4.0)
# Requirement already satisfied: filelock in c:\users\nacer\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\nacer\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in c:\users\nacer\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\nacer\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\nacer\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\nacer\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\nacer\anaconda3\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\nacer\anaconda3\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: wcwidth in c:\users\nacer\anaconda3\lib\site-packages (from ftfy) (0.2.5)
# Requirement already satisfied: colorama in c:\users\nacer\anaconda3\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nacer\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to c:\users\nacer\appdata\local\temp\pip-req-build-ujhwb6br
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: ftfy in c:\users\nacer\anaconda3\lib\site-packages (from clip==1.0) (6.3.1)
# Requirement already satisfied: packaging in c:\users\nacer\anaconda3\lib\site-packages (from clip==1.0) (24.1)
# Requirement already satisfied: regex in c:\users\nacer\anaconda3\lib\site-packages (from clip==1.0) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\nacer\anaconda3\lib\site-packages (from clip==1.0) (4.66.5)
# Requirement already satisfied: torch in c:\users\nacer\anaconda3\lib\site-packages (from clip==1.0) (2.6.0)
# Requirement already satisfied: torchvision in c:\users\nacer\anaconda3\lib\site-packages (from clip==1.0) (0.21.0)
# Requirement already satisfied: wcwidth in c:\users\nacer\anaconda3\lib\site-packages (from ftfy->clip==1.0) (0.2.5)
# Requirement already satisfied: filelock in c:\users\nacer\anaconda3\lib\site-packages (from torch->clip==1.0) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\nacer\anaconda3\lib\site-packages (from torch->clip==1.0) (4.11.0)
# Requirement already satisfied: networkx in c:\users\nacer\anaconda3\lib\site-packages (from torch->clip==1.0) (3.3)
# Requirement already satisfied: jinja2 in c:\users\nacer\anaconda3\lib\site-packages (from torch->clip==1.0) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\nacer\anaconda3\lib\site-packages (from torch->clip==1.0) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\nacer\anaconda3\lib\site-packages (from torch->clip==1.0) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\nacer\anaconda3\lib\site-packages (from torch->clip==1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\nacer\anaconda3\lib\site-packages (from sympy==1.13.1->torch->clip==1.0) (1.3.0)
# Requirement already satisfied: numpy in c:\users\nacer\anaconda3\lib\site-packages (from torchvision->clip==1.0) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\nacer\anaconda3\lib\site-packages (from torchvision->clip==1.0) (10.4.0)
# Requirement already satisfied: colorama in c:\users\nacer\anaconda3\lib\site-packages (from tqdm->clip==1.0) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\nacer\anaconda3\lib\site-packages (from jinja2->torch->clip==1.0) (2.1.3)
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git 'C:\Users\nacer\AppData\Local\Temp\pip-req-build-ujhwb6br'

# %%
# 📦 Imports nécessaires
import os
import torch
import clip
from PIL import Image
import cv2
import subprocess

# %%
# 🏷️ Définition des comportements du chat (labels CLIP)
labels = [
    "a cat playing with a toy",
    "a cat sleeping curled up",
    "a cat eating from a bowl",
    "a cat grooming itself",
    "a cat walking around",
    "a cat jumping",
    "a cat looking at the camera",
    "a cat hiding under furniture",
    "a cat running fast",
    "a cat sitting still",
    "a cat meowing with its mouth open",
    "a cat interacting affectionately with a human"
]
for label in labels:
    folder = f"clips_output/{label.replace(' ', '_')}"
    os.makedirs(folder, exist_ok=True)

# %%
# 🧠 Chargement du modèle CLIP
device = "cuda" if torch.cuda.is_available() else "cpu"
model, preprocess = clip.load("ViT-B/32", device=device)
text_tokens = clip.tokenize(labels).to(device)

# %%
# 🎞️ Extraction des frames d’une vidéo
def extract_frames(video_path, output_folder, frame_rate=1):
    os.makedirs(output_folder, exist_ok=True)
    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)
    interval = int(fps * frame_rate)
    count = 0
    img_count = 0

    while True:
        ret, frame = cap.read()
        if not ret:
            break
        if count % interval == 0:
            frame_path = os.path.join(output_folder, f"frame_{img_count}.jpg")
            cv2.imwrite(frame_path, frame)
            img_count += 1
        count += 1
    cap.release()

# %%
# 🏷️ Classification d’une frame avec CLIP
def classify_frame(image_path):
    image = preprocess(Image.open(image_path)).unsqueeze(0).to(device)
    with torch.no_grad():
        logits_per_image, _ = model(image, text_tokens)
        probs = logits_per_image.softmax(dim=-1).cpu().numpy()
    return labels[probs.argmax()], probs.max()

# %%
# ✂️ Découpe d’un extrait vidéo avec ffmpeg
def extract_clip(video_path, start_time, end_time, output_path):
    cmd = [
        "ffmpeg", "-i", video_path,
        "-ss", str(start_time),
        "-to", str(end_time),
        "-c", "copy", output_path
    ]
    subprocess.run(cmd, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

# %%
# 🧩 Traitement complet d'une vidéo (extraction + classification + découpe)
def process_video(video_path):
    basename = os.path.basename(video_path).split('.')[0]
    frames_folder = f"extracted_frames/{basename}"
    extract_frames(video_path, frames_folder)

    frame_files = sorted(os.listdir(frames_folder))
    if not frame_files:
        print(f"⚠️ Aucune frame extraite pour {basename}, vidéo ignorée.")
        return

    timestamps = []
    for i, filename in enumerate(frame_files):
        label, prob = classify_frame(os.path.join(frames_folder, filename))
        timestamps.append((i, label))

    grouped = []
    current_label = timestamps[0][1]
    start = timestamps[0][0]
    for i in range(1, len(timestamps)):
        if timestamps[i][1] != current_label:
            grouped.append((current_label, start, timestamps[i-1][0]))
            current_label = timestamps[i][1]
            start = timestamps[i][0]
    grouped.append((current_label, start, timestamps[-1][0]))

    for idx, (label, start_frame, end_frame) in enumerate(grouped):
        duration = end_frame - start_frame + 1  # approx en secondes si frame_rate=1

        if duration < 2:
            print(f"⏩ Clip ignoré ({label}) – durée trop courte : {duration} sec")
            continue  # on passe au suivant

        output_name = f"clips_output/{label.replace(' ', '_')}/{basename}_{label.replace(' ', '_')}_{idx}.mp4"
        extract_clip(video_path, start_frame, end_frame + 1, output_name)

# %%
# 🔁 Traitement automatique de toutes les vidéos .mp4 et .mov
for video in os.listdir("input_videos"):
    if video.lower().endswith((".mp4", ".mov")):
        print(f"▶️ Traitement de : {video}")
        process_video(f"input_videos/{video}")
# Out:
# ▶️ Traitement de : 003248DE-A118-43DC-8A99-FB8468499114.mp4
# ⏩ Clip ignoré (a cat looking at the camera) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat hiding under furniture) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat sleeping curled up) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat hiding under furniture) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat looking at the camera) – durée trop courte : 1 sec
#
# ⏩ Clip ignoré (a cat meowing with its mouth open) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat eating from a bowl) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat playing with a toy) – durée trop courte : 1 sec
# ▶️ Traitement de : IMG_8276.MOV
# ▶️ Traitement de : IMG_8277.MOV
# ⏩ Clip ignoré (a cat playing with a toy) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat grooming itself) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat playing with a toy) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat grooming itself) – durée trop courte : 1 sec
# ▶️ Traitement de : IMG_8278.MOV
# ⏩ Clip ignoré (a cat eating from a bowl) – durée trop courte : 1 sec
# ▶️ Traitement de : IMG_8279.MOV
# ⏩ Clip ignoré (a cat eating from a bowl) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat grooming itself) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat playing with a toy) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat grooming itself) – durée trop courte : 1 sec
# ▶️ Traitement de : IMG_8280.MOV
# ⏩ Clip ignoré (a cat meowing with its mouth open) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat playing with a toy) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat grooming itself) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat grooming itself) – durée trop courte : 1 sec
# ▶️ Traitement de : IMG_8281.MOV
# ⏩ Clip ignoré (a cat playing with a toy) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat grooming itself) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat jumping) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat grooming itself) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat eating from a bowl) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat grooming itself) – durée trop courte : 1 sec
# ▶️ Traitement de : IMG_8282.MOV
# ▶️ Traitement de : IMG_8283.MOV
# ⏩ Clip ignoré (a cat hiding under furniture) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat meowing with its mouth open) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat grooming itself) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat hiding under furniture) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat running fast) – durée trop courte : 1 sec
# ▶️ Traitement de : IMG_8284.MOV
# ⏩ Clip ignoré (a cat hiding under furniture) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat playing with a toy) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat hiding under furniture) – durée trop courte : 1 sec
# ▶️ Traitement de : IMG_8285.MOV
# ▶️ Traitement de : IMG_8286.MOV
# ▶️ Traitement de : IMG_8287.MOV
# ⏩ Clip ignoré (a cat hiding under furniture) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat jumping) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat playing with a toy) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat playing with a toy) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat playing with a toy) – durée trop courte : 1 sec
# ▶️ Traitement de : IMG_8288.MOV
# ⏩ Clip ignoré (a cat jumping) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat playing with a toy) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat grooming itself) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat meowing with its mouth open) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat eating from a bowl) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat playing with a toy) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat jumping) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat grooming itself) – durée trop courte : 1 sec
# ▶️ Traitement de : IMG_8289.MOV
# ⏩ Clip ignoré (a cat grooming itself) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat sleeping curled up) – durée trop courte : 1 sec
# ▶️ Traitement de : IMG_8290.MOV
# ⏩ Clip ignoré (a cat grooming itself) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat running fast) – durée trop courte : 1 sec
# ▶️ Traitement de : IMG_8291.MOV
# ⏩ Clip ignoré (a cat looking at the camera) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat meowing with its mouth open) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat grooming itself) – durée trop courte : 1 sec
# ▶️ Traitement de : IMG_8292.MOV
# ⏩ Clip ignoré (a cat grooming itself) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat running fast) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat meowing with its mouth open) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat meowing with its mouth open) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat grooming itself) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat meowing with its mouth open) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat grooming itself) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat meowing with its mouth open) – durée trop courte : 1 sec
# ▶️ Traitement de : IMG_8293.MOV
# ⏩ Clip ignoré (a cat meowing with its mouth open) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat hiding under furniture) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat meowing with its mouth open) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat playing with a toy) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat playing with a toy) – durée trop courte : 1 sec
# ▶️ Traitement de : IMG_8294.MOV
# ⏩ Clip ignoré (a cat looking at the camera) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat hiding under furniture) – durée trop courte : 1 sec
# ▶️ Traitement de : IMG_8295.MOV
# ⏩ Clip ignoré (a cat sleeping curled up) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat meowing with its mouth open) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat eating from a bowl) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat meowing with its mouth open) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat grooming itself) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat meowing with its mouth open) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat grooming itself) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat meowing with its mouth open) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat playing with a toy) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat meowing with its mouth open) – durée trop courte : 1 sec
# ▶️ Traitement de : IMG_8296.MOV
# ⏩ Clip ignoré (a cat grooming itself) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat looking at the camera) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat eating from a bowl) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat meowing with its mouth open) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat eating from a bowl) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat meowing with its mouth open) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat playing with a toy) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat jumping) – durée trop courte : 1 sec
# ⏩ Clip ignoré (a cat meowing with its mouth open) – durée trop courte : 1 sec

# %%
import os
import cv2

input_dir = "input_videos"
output_dir = "clips_output"

# 📦 1. Nombre de vidéos brutes
raw_videos = [f for f in os.listdir(input_dir) if f.lower().endswith((".mp4", ".mov"))]
nb_raw_videos = len(raw_videos)

# 📁 2. Parcours des clips générés
total_clips = 0
total_duration_sec = 0
clips_per_category = {}

for category in os.listdir(output_dir):
    cat_path = os.path.join(output_dir, category)
    if os.path.isdir(cat_path):
        clips = [f for f in os.listdir(cat_path) if f.endswith(".mp4")]
        clips_per_category[category] = len(clips)
        total_clips += len(clips)
        
        # Calculer la durée totale
        for clip in clips:
            clip_path = os.path.join(cat_path, clip)
            cap = cv2.VideoCapture(clip_path)
            fps = cap.get(cv2.CAP_PROP_FPS)
            frame_count = cap.get(cv2.CAP_PROP_FRAME_COUNT)
            duration = frame_count / fps if fps > 0 else 0
            total_duration_sec += duration
            cap.release()

# ⏱️ 3. Moyenne durée clip
avg_duration = total_duration_sec / total_clips if total_clips > 0 else 0

# 📊 Résumé
print("📊 Statistiques du traitement vidéo :\n")
print(f"🎥 Vidéos brutes traitées : {nb_raw_videos}")
print(f"🎬 Clips générés : {total_clips}")
print(f"⏱️ Durée moyenne par clip : {avg_duration:.1f} sec")
print("🗂️ Répartition par catégorie :")
for cat, count in clips_per_category.items():
    print(f"   - {cat} : {count} clips")
# Out:
# 📊 Statistiques du traitement vidéo :
#
# 🎥 Vidéos brutes traitées : 358
# 🎬 Clips générés : 1157
# ⏱️ Durée moyenne par clip : 3.0 sec
# 🗂️ Répartition par catégorie :
#    - a_cat_eating_from_a_bowl : 57 clips
#    - a_cat_grooming_itself : 248 clips
#    - a_cat_hiding_under_furniture : 146 clips
#    - a_cat_interacting_affectionately_with_a_human : 160 clips
#    - a_cat_jumping : 113 clips
#    - a_cat_looking_at_the_camera : 44 clips
#    - a_cat_meowing_with_its_mouth_open : 55 clips
#    - a_cat_playing_with_a_toy : 151 clips
#    - a_cat_running_fast : 56 clips
#    - a_cat_sitting_still : 6 clips
#    - a_cat_sleeping_curled_up : 74 clips
#    - a_cat_walking_around : 47 clips
